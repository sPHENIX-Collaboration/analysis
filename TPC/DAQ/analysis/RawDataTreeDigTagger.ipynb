# %%
# imports to write dynamic markdown contents
import os
from IPython.display import display, Markdown, Latex
from IPython.display import HTML

import pandas as pd
from collections import OrderedDict

import pprint
import re
import numpy as np
import matplotlib.pyplot as plt
import random

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
import plotly.express as px
init_notebook_mode(connected=True)  
import glob
import uproot 
import ROOT

import platform
print('Python:', platform.python_version())
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Welcome to JupyROOT 6.26/06
# Python: 3.10.8

# %%
# run = 10645
# run = 10647
# run = 10648
#  filenames = glob.glob(f"/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc*_pedestal-*{run}-0000.prdf.root")

# run = 10684
# filenames = glob.glob(f"/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc*_beam-*{run}-0000.prdf_skip500.root")
# filenames = glob.glob(f"/sphenix/user/rosstom/test/testFiles/TPC_ebdc*_beam-00010684-0005.prdf_TPCRawDataTree.root")

# run = 10762
# run = 10771
# filenames = glob.glob(f"/sphenix/u/adityadash/sPHENIX_github/analysis/TPC/DAQ/macros/beam-datalocal/TPC_ebdc*_beam-*{run}-0000.prdf_TPCRawDataTree.root")

run = 10790
filenames = glob.glob(f"/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc*_calib-*{run}-0000.prdf.root")
filenames.sort()
pprint.pprint(filenames)
# Out:
# ['/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc00_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc01_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc02_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc03_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc04_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc05_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc06_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc07_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc08_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc09_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc10_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc11_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc12_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc13_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc14_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc15_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc16_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc17_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc18_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc19_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc20_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc21_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc22_calib-00010790-0000.prdf.root',
#  '/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc23_calib-00010790-0000.prdf.root']

# %%
files = dict()
for filename in filenames: 
    
    try:
    
        file = ROOT.TFile.Open(filename)
        sector = re.match(".*ebdc([0-9][0-9])_.*", filename).group(1)
        files[sector] = file

    except:
        pass
        

pprint.pprint(files);
# Out:
# {'00': <cppyy.gbl.TFile object at 0x90bc780>,
#  '01': <cppyy.gbl.TFile object at 0x90fe340>,
#  '02': <cppyy.gbl.TFile object at 0x931d260>,
#  '03': <cppyy.gbl.TFile object at 0x931eb30>,
#  '04': <cppyy.gbl.TFile object at 0x93df380>,
#  '05': <cppyy.gbl.TFile object at 0x93fff90>,
#  '06': <cppyy.gbl.TFile object at 0x9317060>,
#  '07': <cppyy.gbl.TFile object at 0x9319c70>,
#  '08': <cppyy.gbl.TFile object at 0x9426fa0>,
#  '09': <cppyy.gbl.TFile object at 0x9429a40>,
#  '10': <cppyy.gbl.TFile object at 0x94375c0>,
#  '11': <cppyy.gbl.TFile object at 0x943a670>,
#  '12': <cppyy.gbl.TFile object at 0x943d140>,
#  '13': <cppyy.gbl.TFile object at 0x943e7e0>,
#  '14': <cppyy.gbl.TFile object at 0x9486500>,
#  '15': <cppyy.gbl.TFile object at 0x94890a0>,
#  '16': <cppyy.gbl.TFile object at 0x948bbc0>,
#  '17': <cppyy.gbl.TFile object at 0x949e840>,
#  '18': <cppyy.gbl.TFile object at 0x94a12b0>,
#  '19': <cppyy.gbl.TFile object at 0x94a3f50>,
#  '20': <cppyy.gbl.TFile object at 0x94a6af0>,
#  '21': <cppyy.gbl.TFile object at 0x94a9690>,
#  '22': <cppyy.gbl.TFile object at 0x94ac0f0>,
#  '23': <cppyy.gbl.TFile object at 0x94bf170>}

# %%
files['02'].ls()
files['02'].PacketTree.Show(0)
files['02'].SampleTree.Show(0)
files['02'].TaggerTree.Show(0)
# Out:
# TFile**		/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc02_calib-00010790-0000.prdf.root
#  TFile*		/phenix/u/jinhuang/links/sPHENIX_work/TPC/commissioning/TPC_ebdc02_calib-00010790-0000.prdf.root
#   KEY: TTree	PacketTree;1	Each entry is one packet
#   KEY: TTree	SampleTree;1	Each entry is one waveform
#   KEY: TTree	TaggerTree;1	Each entry is one tagger for level 1 trigger or endat tag
# ======> EVENT:0
#  packet          = 4020
#  frame           = 2
#  nWaveormInFrame = 449
#  nTaggerInFrame  = 1
#  maxFEECount     = 26
# ======> EVENT:0
#  packet          = 4020
#  frame           = 2
#  nWaveormInFrame = 449
#  maxFEECount     = 26
#  nSamples        = 360
#  adcSamples      = 71,
#                   75, 69, 68, 70, 71, 66, 65, 74, 71, 68,
#                   71, 66, 71, 64, 67, 71, 70, 68, 72
#  fee             = 25
#  sampaAddress    = 0
#  sampaChannel    = 9
#  Channel         = 9
#  BCO             = 400539
#  checksum        = 50553
#  checksumError   = 0
# ======> EVENT:0
#  packet          = 4020
#  frame           = 2
#  tagger_type     = 48112
#  is_endat        = 0
#  is_lvl1         = 1
#  bco             = 173204344403
#  lvl1_count      = 0
#  endat_count     = 0
#  last_bco        = 168599282003
#  modebits        = 0

# %%
# %%cpp -d
#
# #include<sPhenixStyle.C>

# %%
# %%cpp
#
# SetsPhenixStyle()
# Out:
# sPhenixStyle: Applying nominal settings.
# sPhenixStyle: ROOT6 mode

# %%
# %jsroot on

# %%
# c1 = ROOT.TCanvas( 'TaggerTree', 'TaggerTree', 1400, 1400)

# c1.Divide(4,3)

# i = 1
# for sector, file in files.items():
    

#     pad = c1.cd(i)
#     i=i+1

#     files[sector].TaggerTree.Draw(f"lvl1_count:frame","is_lvl1 && (packet%10==0)");
    
    
# c1.Draw()

# %%
c1 = ROOT.TCanvas( 'ADCQA', 'ADCQA', 500, 500)

files['02'].TaggerTree.Draw(f"lvl1_count:frame","is_lvl1 && (packet%10==0)");
    
c1.Draw("")
# Out:
# <div id="root_plot_1686886918913"
#      style="width: 496px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1686886918913(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.16,"fRightMargin":0.05,"fBottomMargin":0.16,"fTopMargin":0.05,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-3.037974533124,"fY1":-1.4177214487912,"fX2":15.9493670769679,"fY2":7.4430379692517,"fXtoAbsPixelk":79.3600467479707,"fXtoPixelk":79.3600467479707,"fXtoPixel":26.1226668896278,"fYtoAbsPixelk":396.480053094673,"fYtoPixelk":396.480053094673,"fYtoPixel":-53.2685718832271,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":496,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-3.037974533124,"fPixeltoXk":-3.037974533124,"fPixeltoX":0.0382809306655079,"fAbsPixeltoYk":7.4430379692517,"fPixeltoYk":-1.4177214487912,"fPixeltoY":-0.0187727953772095,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":15,"fUymax":7,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":1,"fTicky":1,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":15,"fY2":7,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH2F","fUniqueID":0,"fBits":521,"fName":"htemp","fTitle":"lvl1_count:frame {is_lvl1 && (packet%10==0)}","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":153,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":4194304,"fName":"xaxis","fTitle":"frame","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.05,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.05,"fTitleColor":1,"fTitleFont":42,"fNbins":15,"fXmin":0,"fXmax":15,"fXbins":[],"fFirst":1,"fLast":15,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":4194304,"fName":"yaxis","fTitle":"lvl1_count","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.05,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.05,"fTitleColor":1,"fTitleFont":42,"fNbins":7,"fXmin":0,"fXmax":7,"fXbins":[],"fFirst":1,"fLast":7,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.05,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.05,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":0,"fTsumw":0,"fTsumw2":0,"fTsumwx":0,"fTsumwx2":0,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fBufferSize":3001,"fBuffer":{"$arr":"Float64","len":3001},"fBinStatErrOpt":0,"fStatOverflows":2,"fScalefactor":1,"fTsumwy":0,"fTsumwy2":0,"fTsumwxy":0,"fArray":{"$arr":"Float32","len":153}},{"_typename":"TGraph","fUniqueID":0,"fBits":263177,"fName":"Graph","fTitle":"Graph","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNpoints":7,"fX":{"$arr":"Float64","len":7,"v":[2,5,7,8,10,1 ...

# %%
c1 = ROOT.TCanvas( 'ADCQA', 'ADCQA', 500, 500)

files['02'].SampleTree.Draw("adcSamples[] - adcSamples[0]:frame","checksumError==0 && (adcSamples[] - adcSamples[0])>50 && (adcSamples[] - adcSamples[0])<1000")
    
c1.Draw("")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ADCQA
# <div id="root_plot_1686886920483"
#      style="width: 496px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1686886920483(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.16,"fRightMargin":0.05,"fBottomMargin":0.16,"fTopMargin":0.05,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-2.8354428975824,"fY1":1.51898924709603,"fX2":14.8860759385034,"fY2":242.02531630826,"fXtoAbsPixelk":79.3600467479706,"fXtoPixelk":79.3600467479706,"fXtoPixel":27.9885716674583,"fYtoAbsPixelk":474.981106396271,"fYtoPixelk":474.981106396271,"fYtoPixel":-1.96252633253995,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":496,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-2.8354428975824,"fPixeltoXk":-2.8354428975824,"fPixeltoX":0.0357288686211407,"fAbsPixeltoYk":242.02531630826,"fPixeltoYk":1.51898924709603,"fPixeltoY":-0.509547303095687,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":40,"fUxmax":14,"fUymax":230,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":1,"fTicky":1,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":40,"fX2":14,"fY2":230,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH2F","fUniqueID":0,"fBits":521,"fName":"htemp","fTitle":"adcSamples[] - adcSamples[0]:frame {checksumError==0 && (adcSamples[] - adcSamples[0])>50 && (adcSamples[] - adcSamples[0])<1000}","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":672,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":4194304,"fName":"xaxis","fTitle":"frame","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.05,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.05,"fTitleColor":1,"fTitleFont":42,"fNbins":14,"fXmin":0,"fXmax":14,"fXbins":[],"fFirst":1,"fLast":14,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"adcSamples[] - adcSamples[0]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.05,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.05,"fTitleColor":1,"fTitleFont":42,"fNbins":40,"fXmin":40,"fXmax":230,"fXbins":[],"fFirst":1,"fLast":40,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.05,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.05,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":0,"fTsumw":0,"fTsumw2":0,"fTsumwx":0,"fTsumwx2":0,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fBufferSize":3001,"fBuffer":{"$arr":"Float64","len":3001},"fBinStatErrOpt":0,"fStatOverflows":2,"fScalefactor":1,"fTsumwy":0,"fTsumwy2":0,"fTsumwxy":0,"fArray":{"$arr":"Float32","len":672}},{"_typename":"TGraph","fUniqueID":0,"fBits":263177,"fName":"Graph","fTitle":"Graph","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001," ...

# %%
c1 = ROOT.TCanvas( 'ADCQA', 'ADCQA', 500, 500)

files['02'].SampleTree.Draw("BCO:fee","checksumError==0 &&  (frame==2 || frame==3)")
    
c1.Draw("")
# Out:
# <div id="root_plot_1686886952511"
#      style="width: 496px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1686886952511(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.16,"fRightMargin":0.05,"fBottomMargin":0.16,"fTopMargin":0.05,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-5.8734174307064,"fY1":400535.987341822,"fX2":30.8354430154713,"fY2":400542.316455692,"fXtoAbsPixelk":79.3600467479707,"fXtoPixelk":79.3600467479707,"fXtoPixel":13.5117242532557,"fYtoAbsPixelk":29870844.0469379,"fYtoPixelk":29870844.0469379,"fYtoPixel":-74.5760006363578,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":496,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-5.8734174307064,"fPixeltoXk":-5.8734174307064,"fPixeltoX":0.0740097992866486,"fAbsPixeltoYk":400542.316455692,"fPixeltoYk":400535.987341822,"fPixeltoY":-0.0134091395551785,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":400537,"fUxmax":29,"fUymax":400542,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":1,"fTicky":1,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":400537,"fX2":29,"fY2":400542,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH2F","fUniqueID":0,"fBits":521,"fName":"htemp","fTitle":"BCO:fee {checksumError==0 &&  (frame==2 || frame==3)}","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":217,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":4194304,"fName":"xaxis","fTitle":"fee","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.05,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.05,"fTitleColor":1,"fTitleFont":42,"fNbins":29,"fXmin":0,"fXmax":29,"fXbins":[],"fFirst":1,"fLast":29,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":4194304,"fName":"yaxis","fTitle":"BCO","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.05,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.05,"fTitleColor":1,"fTitleFont":42,"fNbins":5,"fXmin":400537,"fXmax":400542,"fXbins":[],"fFirst":1,"fLast":5,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.05,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.05,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":0,"fTsumw":0,"fTsumw2":0,"fTsumwx":0,"fTsumwx2":0,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fBufferSize":3001,"fBuffer":{"$arr":"Float64","len":3001},"fBinStatErrOpt":0,"fStatOverflows":2,"fScalefactor":1,"fTsumwy":0,"fTsumwy2":0,"fTsumwxy":0,"fArray":{"$arr":"Float32","len":217}},{"_typename":"TGraph","fUniqueID":0,"fBits":263177,"fName":"Graph","fTitle":"Graph","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNpoints":6118,"fX":{"$ar ...

# %%
files['02'].TaggerTree.Scan("packet:bco - (1.732e+11+4344403 ):frame","is_lvl1 &&  (frame==2 || frame==3)")
# Out:
# 2
# ************************************************
# *    Row   *    packet * bco - (1. *     frame *
# ************************************************
# *        0 *      4020 *   4344403 *         2 *
# *        1 *      4021 *   4344403 *         2 *
# ************************************************
# ==> 2 selected entries

# %%
c1 = ROOT.TCanvas( 'TaggerTree', 'TaggerTree', 1400, 1400)

c1.Divide(4,6)

i = 1
for sector, file in files.items():
    

    pad = c1.cd(i)
    i=i+1

    try:
        files[sector].TaggerTree.Draw(f"bco  - (1.732e+11+4344403 ):frame","is_lvl1 && abs (bco  - (1.732e+11+4344403 ))<1.2e6")
        files[sector].TaggerTree.Scan(f"packet:bco   - (1.732e+11+4344403 ):frame","is_lvl1 && abs (bco   - (1.732e+11+4344403 ))<.1e6");
    except: 
        pass
    
c1.Draw()
# Out:
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# *        0 *      4000 *         0 *         2 *
# *        1 *      4001 *         0 *         2 *
# ************************************************
# ==> 2 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# *        0 *      4010 *         0 *         2 *
# *        1 *      4011 *         0 *         2 *
# ************************************************
# ==> 2 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# *        0 *      4020 *         0 *         2 *
# *        1 *      4021 *         0 *         2 *
# ************************************************
# ==> 2 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# *        0 *      4030 *         0 *         2 *
# *        1 *      4031 *         0 *         2 *
# ************************************************
# ==> 2 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# *        0 *      4040 *         0 *         2 *
# *        1 *      4041 *         0 *         2 *
# ************************************************
# ==> 2 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# *        0 *      4050 *        -1 *         2 *
# *        1 *      4051 *        -1 *         2 *
# ************************************************
# ==> 2 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# *        0 *      4060 *         0 *         2 *
# *        1 *      4061 *         0 *         2 *
# ************************************************
# ==> 2 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# *        0 *      4070 *         0 *         2 *
# *        1 *      4071 *         0 *         2 *
# ************************************************
# ==> 2 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# *        0 *      4080 *         0 *         2 *
# *        1 *      4081 *         0 *         2 *
# ************************************************
# ==> 2 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# *        0 *      4090 *         0 *         2 *
# *        1 *      4091 *         0 *         2 *
# ************************************************
# ==> 2 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# *        0 *      4110 *         0 *         2 *
# *        1 *      4111 *         0 *         2 *
# ************************************************
# ==> 2 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# ************************************************
# *    Row   *    packet * bco   - ( *     frame *
# ************************************************
# ************************************************
# ==> 0 selected entries
# <div id="root_plot_1686887035139"
#      style="width: 1396px; height: 1372px">
# </div>
# <script>
#
# function display_root_plot_1686887035139(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.16,"fRightMargin":0.05,"fBottomMargin":0.16,"fTopMargin":0.05,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":1396,"fYtoAbsPixelk":1372.00005,"fYtoPixelk":1372.00005,"fYtoPixel":-1372,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1396,"fVtoAbsPixelk":1372.00005,"fVtoPixelk":1372,"fVtoPixel":-1372,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":7.16332378223496e-4,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-7.28862973760933e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":1,"fTicky":1,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.16,"fRightMargin":0.05,"fBottomMargin":0.16,"fTopMargin":0.05,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.215189813249599,"fY1":-243037.96264992,"fX2":7.37974683078717,"fY2":1275949.36615743,"fXtoAbsPixelk":23.0573139063252,"fXtoPixelk":9.09731421835551,"fXtoPixel":42.2755337763297,"fYtoAbsPixelk":182.750451527878,"fYtoPixelk":169.030451834543,"fYtoPixel":-1.32474223756687e-4,"fUtoAbsPixelk":13.9600496879697,"fUtoPixelk":5e-5,"fUtoPixel":321.080000624061,"fVtoAbsPixelk":214.946716973333,"fVtoPixelk":201.226667279998,"fVtoPixel":-201.226667279998,"fAbsPixeltoXk":-0.545404441924163,"fPixeltoXk":-0.215189813249599,"fPixeltoX":0.0236543435569796,"fAbsPixeltoYk":1379516.68140008,"fPixeltoYk":-243037.96264992,"fPixeltoY":-7548.63830594455,"fXlowNDC":0.00999999977648258,"fYlowNDC":0.843333333109816,"fXUpNDC":0.240000000223517,"fYUpNDC":0.990000000223517,"fWNDC":0.230000000447035,"fHNDC":0.146666667113701,"fAbsXlowNDC":0.00999999977648258,"fAbsYlowNDC":0.843333333109816,"fAbsWNDC":0.230000000447035,"fAbsHNDC":0.146666667113701,"fUxmin":1,"fUymin":0,"fUxmax":7,"fUymax":1200000,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":1,"fTickx":1,"fTicky":1,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":1,"fY1":0,"fX2":7,"fY2":1200000,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH2F","fUniqueID":0,"fBits":521,"fName":"htemp","fTitle":"bco  - (1.732e+11+4344403 ):frame {is_lvl1 && abs (bco  - (1.732e+11+4344403 ))<1.2e6}","fLineColor":1,"fLineStyle":1,"fLineWidth":2,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":20,"fMarkerSize":1.2,"fNcells":336,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":4194304,"fName":"xaxis","fTitle":"frame","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.05,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.05,"fTitleColor":1,"fTitleFont":42,"fNbins":6,"fXmin":1,"fXmax":7,"fXbins":[],"fFirst":1,"fLast":6,"fBits2":0,"fTimeDisp ...

# %%
c1 = ROOT.TCanvas( 'TaggerTree_Check', 'TaggerTree_Check', 1400, 1000)

c1.Divide(1,3)

i = 1

pad = c1.cd(i)
i=i+1

files['16'].TaggerTree.Draw(f"lvl1_count:frame","is_lvl1 && (packet%10==0)");
    
pad = c1.cd(i)
i=i+1

files['16'].TaggerTree.Draw(f"endat_count:frame","is_endat && (packet%10==0)");

pad = c1.cd(i)
i=i+1

files['16'].TaggerTree.Draw(f"lvl1_count-endat_count:frame","is_endat && (packet%10==0)");



c1.Draw()
# Out:
# <div id="root_plot_1686886921136"
#      style="width: 1396px; height: 972px">
# </div>
# <script>
#
# function display_root_plot_1686886921136(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.16,"fRightMargin":0.05,"fBottomMargin":0.16,"fTopMargin":0.05,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":1396,"fYtoAbsPixelk":972.00005,"fYtoPixelk":972.00005,"fYtoPixel":-972,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1396,"fVtoAbsPixelk":972.00005,"fVtoPixelk":972,"fVtoPixel":-972,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":7.16332378223496e-4,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00102880658436214,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":1,"fTicky":1,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.16,"fRightMargin":0.05,"fBottomMargin":0.16,"fTopMargin":0.05,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-3.2405061686656,"fY1":-1.2151898132496,"fX2":17.0126582154325,"fY2":6.37974683078717,"fXtoAbsPixelk":232.852840817988,"fXtoPixelk":218.892841130018,"fXtoPixel":67.548950607354,"fYtoAbsPixelk":265.550452144587,"fYtoPixelk":255.830452361846,"fYtoPixel":-40.1004003994748,"fUtoAbsPixelk":13.9600496879697,"fUtoPixelk":5e-5,"fUtoPixel":1368.08000062406,"fVtoAbsPixelk":314.280050217259,"fVtoPixelk":304.560000434518,"fVtoPixel":-304.560000434518,"fAbsPixeltoXk":-3.44717110664688,"fPixeltoXk":-3.2405061686656,"fPixeltoX":0.0148040789828514,"fAbsPixeltoYk":6.62213842004593,"fPixeltoYk":-1.2151898132496,"fPixeltoY":-0.0249374068597354,"fXlowNDC":0.00999999977648258,"fYlowNDC":0.676666666443149,"fXUpNDC":0.990000000223517,"fYUpNDC":0.990000000223517,"fWNDC":0.980000000447035,"fHNDC":0.313333333780368,"fAbsXlowNDC":0.00999999977648258,"fAbsYlowNDC":0.676666666443149,"fAbsWNDC":0.980000000447035,"fAbsHNDC":0.313333333780368,"fUxmin":0,"fUymin":0,"fUxmax":16,"fUymax":6,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":1,"fTickx":1,"fTicky":1,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":16,"fY2":6,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH2F","fUniqueID":0,"fBits":521,"fName":"htemp","fTitle":"lvl1_count:frame {is_lvl1 && (packet%10==0)}","fLineColor":1,"fLineStyle":1,"fLineWidth":2,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":20,"fMarkerSize":1.2,"fNcells":144,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":4194304,"fName":"xaxis","fTitle":"frame","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.05,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":0.05,"fTitleColor":1,"fTitleFont":42,"fNbins":16,"fXmin":0,"fXmax":16,"fXbins":[],"fFirst":1,"fLast":16,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"f ...
