# %%
import ROOT
from ROOT import TCanvas, TFile, TProfile, TNtuple, TH1I, TH1F, TH2F, TH3F, TColor, TEfficiency
from ROOT import gROOT, gBenchmark, gRandom, gSystem
import numpy as np
import pdb
# Out:
# Welcome to JupyROOT 6.26/06

# %%
# %cd /sphenix/u/egm2153/spring_2023
gROOT.LoadMacro("sPhenixStyle.C");
gROOT.ProcessLine("SetsPhenixStyle()")
# Out:
# /direct/sphenix+u/egm2153/spring_2023
# 0
# sPhenixStyle: Applying nominal settings.
# sPhenixStyle: ROOT6 mode

# %%
# %cd /sphenix/user/egm2153/calib_study/JetValidation/analysis
# Out:
# /gpfs/mnt/gpfs02/sphenix/user/egm2153/calib_study/JetValidation/analysis

# %%
#f2 = ROOT.TFile.Open("pt10cut/dijet_calo_analysis_fullrunlist.root")
f2 = ROOT.TFile.Open("ue_unfolding/dijet_calo_analysis_data_pt7cut_wAj.root")
h_ue_towards = TH1F(f2.Get("h_ue_towards"))
h_ue_transverse = TH1F(f2.Get("h_ue_transverse"))
h_ue_away = TH1F(f2.Get("h_ue_away"))
h_ue_xj_towards = TProfile(f2.Get("h_ue_xj_towards"))
h_ue_xj_transverse = TProfile(f2.Get("h_ue_xj_transverse"))
h_ue_xj_away = TProfile(f2.Get("h_ue_xj_away"))
h_ue_towards.Rebin(2)
h_ue_transverse.Rebin(2)
h_ue_away.Rebin(2)
h_ue_towards.Scale(1.0/h_ue_towards.Integral())
h_ue_transverse.Scale(1.0/h_ue_transverse.Integral())
h_ue_away.Scale(1.0/h_ue_away.Integral())
h_ue_towards.SetDirectory(0)
h_ue_transverse.SetDirectory(0)
h_ue_away.SetDirectory(0)
h_ue_xj_towards.SetDirectory(0)
h_ue_xj_transverse.SetDirectory(0)
h_ue_xj_away.SetDirectory(0)
h_ue_pt_towards = TProfile(f2.Get("h_ue_pt_towards"))
h_ue_pt_transverse = TProfile(f2.Get("h_ue_pt_transverse"))
h_ue_pt_away = TProfile(f2.Get("h_ue_pt_away"))
h_ue_pt_towards.SetDirectory(0)
h_ue_pt_transverse.SetDirectory(0)
h_ue_pt_away.SetDirectory(0)

# %%
f2 = ROOT.TFile.Open("ue_unfolding/dijet_calo_analysis_waveform_simulation_unfolding_pt7cut_wAj.root")
h_mc_ue_towards = TH1F(f2.Get("h_ue_towards"))
h_mc_ue_transverse = TH1F(f2.Get("h_ue_transverse"))
h_mc_ue_away = TH1F(f2.Get("h_ue_away"))
h_mc_ue_xj_towards = TProfile(f2.Get("h_ue_xj_towards"))
h_mc_ue_xj_transverse = TProfile(f2.Get("h_ue_xj_transverse"))
h_mc_ue_xj_away = TProfile(f2.Get("h_ue_xj_away"))
h_mc_ue_towards.Rebin(2)
h_mc_ue_transverse.Rebin(2)
h_mc_ue_away.Rebin(2)
h_mc_ue_towards.Scale(1.0/h_mc_ue_towards.Integral())
h_mc_ue_transverse.Scale(1.0/h_mc_ue_transverse.Integral())
h_mc_ue_away.Scale(1.0/h_mc_ue_away.Integral())
h_mc_ue_towards.SetDirectory(0)
h_mc_ue_transverse.SetDirectory(0)
h_mc_ue_away.SetDirectory(0)
h_mc_ue_xj_towards.SetDirectory(0)
h_mc_ue_xj_transverse.SetDirectory(0)
h_mc_ue_xj_away.SetDirectory(0)
h_mc_ue_pt_towards = TProfile(f2.Get("h_ue_pt_towards"))
h_mc_ue_pt_transverse = TProfile(f2.Get("h_ue_pt_transverse"))
h_mc_ue_pt_away = TProfile(f2.Get("h_ue_pt_away"))
h_mc_ue_pt_towards.SetDirectory(0)
h_mc_ue_pt_transverse.SetDirectory(0)
h_mc_ue_pt_away.SetDirectory(0)
f2 = ROOT.TFile.Open("ue_unfolding/dijet_calo_analysis_cluster_simulation_unfolding_pt7cut_wAj.root")
h_clus_ue_towards = TH1F(f2.Get("h_ue_towards"))
h_clus_ue_transverse = TH1F(f2.Get("h_ue_transverse"))
h_clus_ue_away = TH1F(f2.Get("h_ue_away"))
h_clus_ue_xj_towards = TProfile(f2.Get("h_ue_xj_towards"))
h_clus_ue_xj_transverse = TProfile(f2.Get("h_ue_xj_transverse"))
h_clus_ue_xj_away = TProfile(f2.Get("h_ue_xj_away"))
h_clus_ue_towards.Rebin(2)
h_clus_ue_transverse.Rebin(2)
h_clus_ue_away.Rebin(2)
h_clus_ue_towards.Scale(1.0/h_clus_ue_towards.Integral())
h_clus_ue_transverse.Scale(1.0/h_clus_ue_transverse.Integral())
h_clus_ue_away.Scale(1.0/h_clus_ue_away.Integral())
h_clus_ue_towards.SetDirectory(0)
h_clus_ue_transverse.SetDirectory(0)
h_clus_ue_away.SetDirectory(0)
h_clus_ue_xj_towards.SetDirectory(0)
h_clus_ue_xj_transverse.SetDirectory(0)
h_clus_ue_xj_away.SetDirectory(0)
h_clus_ue_pt_towards = TProfile(f2.Get("h_ue_pt_towards"))
h_clus_ue_pt_transverse = TProfile(f2.Get("h_ue_pt_transverse"))
h_clus_ue_pt_away = TProfile(f2.Get("h_ue_pt_away"))
h_clus_ue_pt_towards.SetDirectory(0)
h_clus_ue_pt_transverse.SetDirectory(0)
h_clus_ue_pt_away.SetDirectory(0)
f2.Close()
f2 = ROOT.TFile.Open("ue_unfolding/dijet_calo_analysis_nozero_simulation_unfolding_pt7cut_wAj.root")
h_nz_ue_towards = TH1F(f2.Get("h_ue_towards"))
h_nz_ue_transverse = TH1F(f2.Get("h_ue_transverse"))
h_nz_ue_away = TH1F(f2.Get("h_ue_away"))
h_nz_ue_xj_towards = TProfile(f2.Get("h_ue_xj_towards"))
h_nz_ue_xj_transverse = TProfile(f2.Get("h_ue_xj_transverse"))
h_nz_ue_xj_away = TProfile(f2.Get("h_ue_xj_away"))
h_nz_ue_towards.Rebin(2)
h_nz_ue_transverse.Rebin(2)
h_nz_ue_away.Rebin(2)
h_nz_ue_towards.Scale(1.0/h_nz_ue_towards.Integral())
h_nz_ue_transverse.Scale(1.0/h_nz_ue_transverse.Integral())
h_nz_ue_away.Scale(1.0/h_nz_ue_away.Integral())
h_nz_ue_towards.SetDirectory(0)
h_nz_ue_transverse.SetDirectory(0)
h_nz_ue_away.SetDirectory(0)
h_nz_ue_xj_towards.SetDirectory(0)
h_nz_ue_xj_transverse.SetDirectory(0)
h_nz_ue_xj_away.SetDirectory(0)
h_nz_ue_pt_towards = TProfile(f2.Get("h_ue_pt_towards"))
h_nz_ue_pt_transverse = TProfile(f2.Get("h_ue_pt_transverse"))
h_nz_ue_pt_away = TProfile(f2.Get("h_ue_pt_away"))
h_nz_ue_pt_towards.SetDirectory(0)
h_nz_ue_pt_transverse.SetDirectory(0)
h_nz_ue_pt_away.SetDirectory(0)
f2.Close()
f2 = ROOT.TFile.Open("ue_unfolding/dijet_calo_analysis_detroit_jet10_simulation_unfolding_pt7cut_wAj.root")
h_dt_ue_towards = TH1F(f2.Get("h_ue_towards"))
h_dt_ue_transverse = TH1F(f2.Get("h_ue_transverse"))
h_dt_ue_away = TH1F(f2.Get("h_ue_away"))
h_dt_ue_xj_towards = TProfile(f2.Get("h_ue_xj_towards"))
h_dt_ue_xj_transverse = TProfile(f2.Get("h_ue_xj_transverse"))
h_dt_ue_xj_away = TProfile(f2.Get("h_ue_xj_away"))
h_dt_ue_towards.Rebin(2)
h_dt_ue_transverse.Rebin(2)
h_dt_ue_away.Rebin(2)
h_dt_ue_towards.Scale(1.0/h_dt_ue_towards.Integral())
h_dt_ue_transverse.Scale(1.0/h_dt_ue_transverse.Integral())
h_dt_ue_away.Scale(1.0/h_dt_ue_away.Integral())
h_dt_ue_towards.SetDirectory(0)
h_dt_ue_transverse.SetDirectory(0)
h_dt_ue_away.SetDirectory(0)
h_dt_ue_xj_towards.SetDirectory(0)
h_dt_ue_xj_transverse.SetDirectory(0)
h_dt_ue_xj_away.SetDirectory(0)
h_dt_ue_pt_towards = TProfile(f2.Get("h_ue_pt_towards"))
h_dt_ue_pt_transverse = TProfile(f2.Get("h_ue_pt_transverse"))
h_dt_ue_pt_away = TProfile(f2.Get("h_ue_pt_away"))
h_dt_ue_pt_towards.SetDirectory(0)
h_dt_ue_pt_transverse.SetDirectory(0)
h_dt_ue_pt_away.SetDirectory(0)
f2.Close()

# %%
f2 = ROOT.TFile.Open("ue_unfolding/dijet_calo_analysis_data_topo_pt7cut_wAj.root")
h1_ue_towards = TH1F(f2.Get("h_ue_towards"))
h1_ue_transverse = TH1F(f2.Get("h_ue_transverse"))
h1_ue_away = TH1F(f2.Get("h_ue_away"))
h1_ue_xj_towards = TProfile(f2.Get("h_ue_xj_towards"))
h1_ue_xj_transverse = TProfile(f2.Get("h_ue_xj_transverse"))
h1_ue_xj_away = TProfile(f2.Get("h_ue_xj_away"))
h1_ue_towards.Rebin(2)
h1_ue_transverse.Rebin(2)
h1_ue_away.Rebin(2)
h1_ue_towards.Scale(1.0/h1_ue_towards.Integral())
h1_ue_transverse.Scale(1.0/h1_ue_transverse.Integral())
h1_ue_away.Scale(1.0/h1_ue_away.Integral())
h1_ue_towards.SetDirectory(0)
h1_ue_transverse.SetDirectory(0)
h1_ue_away.SetDirectory(0)
h1_ue_xj_towards.SetDirectory(0)
h1_ue_xj_transverse.SetDirectory(0)
h1_ue_xj_away.SetDirectory(0)
h1_ue_pt_towards = TProfile(f2.Get("h_ue_pt_towards"))
h1_ue_pt_transverse = TProfile(f2.Get("h_ue_pt_transverse"))
h1_ue_pt_away = TProfile(f2.Get("h_ue_pt_away"))
h1_ue_pt_towards.SetDirectory(0)
h1_ue_pt_transverse.SetDirectory(0)
h1_ue_pt_away.SetDirectory(0)

# %%
f2 = ROOT.TFile.Open("ue_unfolding/dijet_calo_analysis_waveform_topocluster_simulation_unfolding_pt7cut_wAj.root")
h1_mc_ue_towards = TH1F(f2.Get("h_ue_towards"))
h1_mc_ue_transverse = TH1F(f2.Get("h_ue_transverse"))
h1_mc_ue_away = TH1F(f2.Get("h_ue_away"))
h1_mc_ue_xj_towards = TProfile(f2.Get("h_ue_xj_towards"))
h1_mc_ue_xj_transverse = TProfile(f2.Get("h_ue_xj_transverse"))
h1_mc_ue_xj_away = TProfile(f2.Get("h_ue_xj_away"))
h1_mc_ue_towards.Rebin(2)
h1_mc_ue_transverse.Rebin(2)
h1_mc_ue_away.Rebin(2)
h1_mc_ue_towards.Scale(1.0/h1_mc_ue_towards.Integral())
h1_mc_ue_transverse.Scale(1.0/h1_mc_ue_transverse.Integral())
h1_mc_ue_away.Scale(1.0/h1_mc_ue_away.Integral())
h1_mc_ue_towards.SetDirectory(0)
h1_mc_ue_transverse.SetDirectory(0)
h1_mc_ue_away.SetDirectory(0)
h1_mc_ue_xj_towards.SetDirectory(0)
h1_mc_ue_xj_transverse.SetDirectory(0)
h1_mc_ue_xj_away.SetDirectory(0)
h1_mc_ue_pt_towards = TProfile(f2.Get("h_ue_pt_towards"))
h1_mc_ue_pt_transverse = TProfile(f2.Get("h_ue_pt_transverse"))
h1_mc_ue_pt_away = TProfile(f2.Get("h_ue_pt_away"))
h1_mc_ue_pt_towards.SetDirectory(0)
h1_mc_ue_pt_transverse.SetDirectory(0)
h1_mc_ue_pt_away.SetDirectory(0)
f2 = ROOT.TFile.Open("ue_unfolding/dijet_calo_analysis_cluster_topocluster_simulation_unfolding_pt7cut_wAj.root")
h1_clus_ue_towards = TH1F(f2.Get("h_ue_towards"))
h1_clus_ue_transverse = TH1F(f2.Get("h_ue_transverse"))
h1_clus_ue_away = TH1F(f2.Get("h_ue_away"))
h1_clus_ue_xj_towards = TProfile(f2.Get("h_ue_xj_towards"))
h1_clus_ue_xj_transverse = TProfile(f2.Get("h_ue_xj_transverse"))
h1_clus_ue_xj_away = TProfile(f2.Get("h_ue_xj_away"))
h1_clus_ue_towards.Rebin(2)
h1_clus_ue_transverse.Rebin(2)
h1_clus_ue_away.Rebin(2)
h1_clus_ue_towards.Scale(1.0/h1_clus_ue_towards.Integral())
h1_clus_ue_transverse.Scale(1.0/h1_clus_ue_transverse.Integral())
h1_clus_ue_away.Scale(1.0/h1_clus_ue_away.Integral())
h1_clus_ue_towards.SetDirectory(0)
h1_clus_ue_transverse.SetDirectory(0)
h1_clus_ue_away.SetDirectory(0)
h1_clus_ue_xj_towards.SetDirectory(0)
h1_clus_ue_xj_transverse.SetDirectory(0)
h1_clus_ue_xj_away.SetDirectory(0)
h1_clus_ue_pt_towards = TProfile(f2.Get("h_ue_pt_towards"))
h1_clus_ue_pt_transverse = TProfile(f2.Get("h_ue_pt_transverse"))
h1_clus_ue_pt_away = TProfile(f2.Get("h_ue_pt_away"))
h1_clus_ue_pt_towards.SetDirectory(0)
h1_clus_ue_pt_transverse.SetDirectory(0)
h1_clus_ue_pt_away.SetDirectory(0)
f2.Close()
f2 = ROOT.TFile.Open("ue_unfolding/dijet_calo_analysis_nozero_topocluster_simulation_unfolding_pt7cut_wAj.root")
h1_nz_ue_towards = TH1F(f2.Get("h_ue_towards"))
h1_nz_ue_transverse = TH1F(f2.Get("h_ue_transverse"))
h1_nz_ue_away = TH1F(f2.Get("h_ue_away"))
h1_nz_ue_xj_towards = TProfile(f2.Get("h_ue_xj_towards"))
h1_nz_ue_xj_transverse = TProfile(f2.Get("h_ue_xj_transverse"))
h1_nz_ue_xj_away = TProfile(f2.Get("h_ue_xj_away"))
h1_nz_ue_towards.Rebin(2)
h1_nz_ue_transverse.Rebin(2)
h1_nz_ue_away.Rebin(2)
h1_nz_ue_towards.Scale(1.0/h1_nz_ue_towards.Integral())
h1_nz_ue_transverse.Scale(1.0/h1_nz_ue_transverse.Integral())
h1_nz_ue_away.Scale(1.0/h1_nz_ue_away.Integral())
h1_nz_ue_towards.SetDirectory(0)
h1_nz_ue_transverse.SetDirectory(0)
h1_nz_ue_away.SetDirectory(0)
h1_nz_ue_xj_towards.SetDirectory(0)
h1_nz_ue_xj_transverse.SetDirectory(0)
h1_nz_ue_xj_away.SetDirectory(0)
h1_nz_ue_pt_towards = TProfile(f2.Get("h_ue_pt_towards"))
h1_nz_ue_pt_transverse = TProfile(f2.Get("h_ue_pt_transverse"))
h1_nz_ue_pt_away = TProfile(f2.Get("h_ue_pt_away"))
h1_nz_ue_pt_towards.SetDirectory(0)
h1_nz_ue_pt_transverse.SetDirectory(0)
h1_nz_ue_pt_away.SetDirectory(0)
f2.Close()
f2 = ROOT.TFile.Open("ue_unfolding/dijet_calo_analysis_detroit_jet10_topocluster_simulation_unfolding_pt7cut_wAj.root")
h1_dt_ue_towards = TH1F(f2.Get("h_ue_towards"))
h1_dt_ue_transverse = TH1F(f2.Get("h_ue_transverse"))
h1_dt_ue_away = TH1F(f2.Get("h_ue_away"))
h1_dt_ue_xj_towards = TProfile(f2.Get("h_ue_xj_towards"))
h1_dt_ue_xj_transverse = TProfile(f2.Get("h_ue_xj_transverse"))
h1_dt_ue_xj_away = TProfile(f2.Get("h_ue_xj_away"))
h1_dt_ue_towards.Rebin(2)
h1_dt_ue_transverse.Rebin(2)
h1_dt_ue_away.Rebin(2)
h1_dt_ue_towards.Scale(1.0/h1_dt_ue_towards.Integral())
h1_dt_ue_transverse.Scale(1.0/h1_dt_ue_transverse.Integral())
h1_dt_ue_away.Scale(1.0/h1_dt_ue_away.Integral())
h1_dt_ue_towards.SetDirectory(0)
h1_dt_ue_transverse.SetDirectory(0)
h1_dt_ue_away.SetDirectory(0)
h1_dt_ue_xj_towards.SetDirectory(0)
h1_dt_ue_xj_transverse.SetDirectory(0)
h1_dt_ue_xj_away.SetDirectory(0)
h1_dt_ue_pt_towards = TProfile(f2.Get("h_ue_pt_towards"))
h1_dt_ue_pt_transverse = TProfile(f2.Get("h_ue_pt_transverse"))
h1_dt_ue_pt_away = TProfile(f2.Get("h_ue_pt_away"))
h1_dt_ue_pt_towards.SetDirectory(0)
h1_dt_ue_pt_transverse.SetDirectory(0)
h1_dt_ue_pt_away.SetDirectory(0)
f2.Close()

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.55,.65,.92,.92)
leg.AddEntry("","#bf{Towards Region}","")
leg.AddEntry(h_ue_towards,"Jet Trig. Data Towers","pl")
leg.AddEntry(h_mc_ue_towards,"Waveform Towers","pl")
leg.AddEntry(h_clus_ue_towards,"Cluster Towers","pl")
leg.AddEntry(h_nz_ue_towards,"No ZS Towers","pl")
leg.AddEntry(h_dt_ue_towards,"Detroit Waveform Towers","pl")
h_ue_towards.SetStats(0)
h_mc_ue_towards.SetStats(0)
h_clus_ue_towards.SetStats(0)
h_nz_ue_towards.SetStats(0)
h_dt_ue_towards.SetStats(0)
h_mc_ue_towards.SetLineColor(2)
h_mc_ue_towards.SetMarkerColor(2)
h_clus_ue_towards.SetLineColor(4)
h_clus_ue_towards.SetMarkerColor(4)
h_nz_ue_towards.SetLineColor(6)
h_nz_ue_towards.SetMarkerColor(6)
h_dt_ue_towards.SetLineColor(7)
h_dt_ue_towards.SetMarkerColor(7)
h_mc_ue_towards.SetMarkerStyle(20)
h_clus_ue_towards.SetMarkerStyle(20)
h_nz_ue_towards.SetMarkerStyle(20)
h_mc_ue_towards.GetXaxis().SetRangeUser(0,20)
h_mc_ue_towards.Draw()
h_dt_ue_towards.Draw('same')
h_clus_ue_towards.Draw('same')
h_nz_ue_towards.Draw('same')
h_ue_towards.Draw('same')
h_mc_ue_towards.SetXTitle("#SigmaE_{T}/#delta#eta#delta#phi [GeV]") 
canvas.SetLogy(1)
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_towards_towers.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_towards_towers.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.55,.65,.92,.92)
leg.AddEntry("","#bf{Transverse Region}","")
leg.AddEntry(h_ue_transverse,"Jet Trig. Data Towers","pl")
leg.AddEntry(h_mc_ue_transverse,"Waveform Towers","pl")
leg.AddEntry(h_clus_ue_transverse,"Cluster Towers","pl")
leg.AddEntry(h_nz_ue_transverse,"No ZS Towers","pl")
leg.AddEntry(h_dt_ue_transverse,"Detroit Waveform Towers","pl")
h_ue_transverse.SetStats(0)
h_mc_ue_transverse.SetStats(0)
h_clus_ue_transverse.SetStats(0)
h_nz_ue_transverse.SetStats(0)
h_dt_ue_transverse.SetStats(0)
h_mc_ue_transverse.SetLineColor(2)
h_mc_ue_transverse.SetMarkerColor(2)
h_clus_ue_transverse.SetLineColor(4)
h_clus_ue_transverse.SetMarkerColor(4)
h_nz_ue_transverse.SetLineColor(6)
h_nz_ue_transverse.SetMarkerColor(6)
h_dt_ue_transverse.SetLineColor(7)
h_dt_ue_transverse.SetMarkerColor(7)
h_mc_ue_transverse.SetMarkerStyle(20)
h_clus_ue_transverse.SetMarkerStyle(20)
h_nz_ue_transverse.SetMarkerStyle(20)
h_mc_ue_transverse.GetXaxis().SetRangeUser(-3,13)
h_mc_ue_transverse.Draw()
h_dt_ue_transverse.Draw('same')
h_clus_ue_transverse.Draw('same')
h_nz_ue_transverse.Draw('same')
h_ue_transverse.Draw('same')
h_mc_ue_transverse.SetXTitle("#SigmaE_{T}/#delta#eta#delta#phi [GeV]") 
canvas.SetLogy(1)
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_transverse_towers.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_transverse_towers.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.55,.65,.92,.92)
leg.AddEntry("","#bf{Away Region}","")
leg.AddEntry(h_ue_away,"Jet Trig. Data Towers","pl")
leg.AddEntry(h_mc_ue_away,"Waveform Towers","pl")
leg.AddEntry(h_clus_ue_away,"Cluster Towers","pl")
leg.AddEntry(h_nz_ue_away,"No ZS Towers","pl")
leg.AddEntry(h_dt_ue_away,"Detroit Waveform Towers","pl")
h_ue_away.SetStats(0)
h_mc_ue_away.SetStats(0)
h_clus_ue_away.SetStats(0)
h_nz_ue_away.SetStats(0)
h_dt_ue_away.SetStats(0)
h_mc_ue_away.SetLineColor(2)
h_mc_ue_away.SetMarkerColor(2)
h_clus_ue_away.SetLineColor(4)
h_clus_ue_away.SetMarkerColor(4)
h_nz_ue_away.SetLineColor(6)
h_nz_ue_away.SetMarkerColor(6)
h_dt_ue_away.SetLineColor(7)
h_dt_ue_away.SetMarkerColor(7)
h_mc_ue_away.SetMarkerStyle(20)
h_clus_ue_away.SetMarkerStyle(20)
h_nz_ue_away.SetMarkerStyle(20)
h_mc_ue_away.GetXaxis().SetRangeUser(-1,20)
h_mc_ue_away.Draw()
h_dt_ue_away.Draw('same')
h_clus_ue_away.Draw('same')
h_nz_ue_away.Draw('same')
h_ue_away.Draw('same')
h_mc_ue_away.SetXTitle("#SigmaE_{T}/#delta#eta#delta#phi [GeV]") 
canvas.SetLogy(1)
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_away_towers.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_away_towers.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.47,.65,.92,.92)
leg.AddEntry("","#bf{Towards Region}","")
leg.AddEntry(h1_ue_towards,"Jet Trig. Data Topoclusters","pl")
leg.AddEntry(h1_mc_ue_towards,"Waveform Topoclusters","pl")
leg.AddEntry(h1_clus_ue_towards,"Cluster Topoclusters","pl")
leg.AddEntry(h1_nz_ue_towards,"No ZS Topoclusters","pl")
leg.AddEntry(h1_dt_ue_towards,"Detroit Waveform Topoclusters","pl")
h1_ue_towards.SetStats(0)
h1_mc_ue_towards.SetStats(0)
h1_clus_ue_towards.SetStats(0)
h1_nz_ue_towards.SetStats(0)
h1_dt_ue_towards.SetStats(0)
h1_mc_ue_towards.SetLineColor(2)
h1_mc_ue_towards.SetMarkerColor(2)
h1_clus_ue_towards.SetLineColor(4)
h1_clus_ue_towards.SetMarkerColor(4)
h1_nz_ue_towards.SetLineColor(6)
h1_nz_ue_towards.SetMarkerColor(6)
h1_dt_ue_towards.SetLineColor(7)
h1_dt_ue_towards.SetMarkerColor(7)
h1_mc_ue_towards.SetMarkerStyle(20)
h1_clus_ue_towards.SetMarkerStyle(20)
h1_nz_ue_towards.SetMarkerStyle(20)
h1_mc_ue_towards.GetXaxis().SetRangeUser(0,20)
h1_mc_ue_towards.Draw()
h1_dt_ue_towards.Draw('same')
h1_clus_ue_towards.Draw('same')
h1_nz_ue_towards.Draw('same')
h1_ue_towards.Draw('same')
h1_mc_ue_towards.SetXTitle("#SigmaE_{T}/#delta#eta#delta#phi [GeV]") 
canvas.SetLogy(1)
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_towards_topoclusters.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_towards_topoclusters.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.47,.65,.92,.92)
leg.AddEntry("","#bf{Transverse Region}","")
leg.AddEntry(h1_ue_transverse,"Jet Trig. Data Topoclusters","pl")
leg.AddEntry(h1_mc_ue_transverse,"Waveform Topoclusters","pl")
leg.AddEntry(h1_clus_ue_transverse,"Cluster Topoclusters","pl")
leg.AddEntry(h1_nz_ue_transverse,"No ZS Topoclusters","pl")
leg.AddEntry(h1_dt_ue_transverse,"Detroit Waveform Topoclusters","pl")
h1_ue_transverse.SetStats(0)
h1_mc_ue_transverse.SetStats(0)
h1_clus_ue_transverse.SetStats(0)
h1_nz_ue_transverse.SetStats(0)
h1_dt_ue_transverse.SetStats(0)
h1_mc_ue_transverse.SetLineColor(2)
h1_mc_ue_transverse.SetMarkerColor(2)
h1_clus_ue_transverse.SetLineColor(4)
h1_clus_ue_transverse.SetMarkerColor(4)
h1_nz_ue_transverse.SetLineColor(6)
h1_nz_ue_transverse.SetMarkerColor(6)
h1_dt_ue_transverse.SetLineColor(7)
h1_dt_ue_transverse.SetMarkerColor(7)
h1_mc_ue_transverse.SetMarkerStyle(20)
h1_clus_ue_transverse.SetMarkerStyle(20)
h1_nz_ue_transverse.SetMarkerStyle(20)
h1_mc_ue_transverse.GetXaxis().SetRangeUser(-3,13)
h1_mc_ue_transverse.Draw()
h1_dt_ue_transverse.Draw('same')
h1_clus_ue_transverse.Draw('same')
h1_nz_ue_transverse.Draw('same')
h1_ue_transverse.Draw('same')
h1_mc_ue_transverse.SetXTitle("#SigmaE_{T}/#delta#eta#delta#phi [GeV]") 
canvas.SetLogy(1)
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_transverse_topoclusters.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_transverse_topoclusters.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.47,.65,.92,.92)
leg.AddEntry("","#bf{Away Region}","")
leg.AddEntry(h1_ue_away,"Jet Trig. Data Topoclusters","pl")
leg.AddEntry(h1_mc_ue_away,"Waveform Topoclusters","pl")
leg.AddEntry(h1_clus_ue_away,"Cluster Topoclusters","pl")
leg.AddEntry(h1_nz_ue_away,"No ZS Topoclusters","pl")
leg.AddEntry(h1_dt_ue_away,"Detroit Waveform Topoclusters","pl")
h1_ue_away.SetStats(0)
h1_mc_ue_away.SetStats(0)
h1_clus_ue_away.SetStats(0)
h1_nz_ue_away.SetStats(0)
h1_dt_ue_away.SetStats(0)
h1_mc_ue_away.SetLineColor(2)
h1_mc_ue_away.SetMarkerColor(2)
h1_clus_ue_away.SetLineColor(4)
h1_clus_ue_away.SetMarkerColor(4)
h1_nz_ue_away.SetLineColor(6)
h1_nz_ue_away.SetMarkerColor(6)
h1_dt_ue_away.SetLineColor(7)
h1_dt_ue_away.SetMarkerColor(7)
h1_mc_ue_away.SetMarkerStyle(20)
h1_clus_ue_away.SetMarkerStyle(20)
h1_nz_ue_away.SetMarkerStyle(20)
h1_mc_ue_away.GetXaxis().SetRangeUser(-1,20)
h1_mc_ue_away.Draw()
h1_dt_ue_away.Draw('same')
h1_clus_ue_away.Draw('same')
h1_nz_ue_away.Draw('same')
h1_ue_away.Draw('same')
h1_mc_ue_away.SetXTitle("#SigmaE_{T}/#delta#eta#delta#phi [GeV]") 
canvas.SetLogy(1)
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_away_topoclusters.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_away_topoclusters.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.48,.64,.92,.92)
leg.AddEntry("","#bf{Towards Region}","")
leg.AddEntry(h_ue_xj_towards,"Jet Trig. Data Towers","pl")
leg.AddEntry(h_mc_ue_xj_towards,"Waveform Towers","pl")
leg.AddEntry(h_clus_ue_xj_towards,"Cluster Towers","pl")
leg.AddEntry(h_nz_ue_xj_towards,"No ZS Towers","pl")
leg.AddEntry(h_dt_ue_xj_towards,"Detroit Waveform Towers","pl")
h_mc_ue_xj_towards.SetStats(0)
h_clus_ue_xj_towards.SetStats(0)
h_nz_ue_xj_towards.SetStats(0)
h_ue_xj_towards.SetStats(0)
h_dt_ue_xj_towards.SetStats(0)
h_mc_ue_xj_towards.SetLineColor(2)
h_mc_ue_xj_towards.SetMarkerColor(2)
h_clus_ue_xj_towards.SetLineColor(4)
h_clus_ue_xj_towards.SetMarkerColor(4)
h_nz_ue_xj_towards.SetLineColor(6)
h_nz_ue_xj_towards.SetMarkerColor(6)
h_ue_xj_towards.SetLineColor(1)
h_ue_xj_towards.SetMarkerColor(1)
h_dt_ue_xj_towards.SetLineColor(7)
h_dt_ue_xj_towards.SetMarkerColor(7)
h_mc_ue_xj_towards.SetMarkerStyle(20)
h_clus_ue_xj_towards.SetMarkerStyle(20)
h_nz_ue_xj_towards.SetMarkerStyle(20)
h_ue_xj_towards.SetMarkerStyle(20)
h_dt_ue_xj_towards.SetMarkerStyle(20)
h_mc_ue_xj_towards.GetYaxis().SetRangeUser(3.5,9)
h_mc_ue_xj_towards.Draw()
h_ue_xj_towards.Draw('same')
h_clus_ue_xj_towards.Draw('same')
h_nz_ue_xj_towards.Draw('same')
h_dt_ue_xj_towards.Draw('same')
h_mc_ue_xj_towards.SetYTitle("<#SigmaE_{T}/#delta#eta#delta#phi> [GeV]") 
h_mc_ue_xj_towards.SetXTitle("x_{j}")
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_xj_towards_towers.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_xj_towards_towers.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.48,.64,.92,.92)
leg.AddEntry("","#bf{Towards Region}","")
leg.AddEntry(h1_ue_xj_towards,"Jet Trig. Data Topoclusters","pl")
leg.AddEntry(h1_mc_ue_xj_towards,"Waveform Topoclusters","pl")
leg.AddEntry(h1_clus_ue_xj_towards,"Cluster Topoclusters","pl")
leg.AddEntry(h1_nz_ue_xj_towards,"No ZS Topoclusters","pl")
leg.AddEntry(h1_dt_ue_xj_towards,"Detroit Waveform Topoclusters","pl")
h1_mc_ue_xj_towards.SetStats(0)
h1_clus_ue_xj_towards.SetStats(0)
h1_nz_ue_xj_towards.SetStats(0)
h1_ue_xj_towards.SetStats(0)
h1_dt_ue_xj_towards.SetStats(0)
h1_mc_ue_xj_towards.SetLineColor(2)
h1_mc_ue_xj_towards.SetMarkerColor(2)
h1_clus_ue_xj_towards.SetLineColor(4)
h1_clus_ue_xj_towards.SetMarkerColor(4)
h1_nz_ue_xj_towards.SetLineColor(6)
h1_nz_ue_xj_towards.SetMarkerColor(6)
h1_ue_xj_towards.SetLineColor(1)
h1_ue_xj_towards.SetMarkerColor(1)
h1_dt_ue_xj_towards.SetLineColor(7)
h1_dt_ue_xj_towards.SetMarkerColor(7)
h1_mc_ue_xj_towards.SetMarkerStyle(20)
h1_clus_ue_xj_towards.SetMarkerStyle(20)
h1_nz_ue_xj_towards.SetMarkerStyle(20)
h1_ue_xj_towards.SetMarkerStyle(20)
h1_dt_ue_xj_towards.SetMarkerStyle(20)
h1_mc_ue_xj_towards.GetYaxis().SetRangeUser(3,9)
h1_mc_ue_xj_towards.Draw()
h1_ue_xj_towards.Draw('same')
h1_clus_ue_xj_towards.Draw('same')
h1_nz_ue_xj_towards.Draw('same')
h1_dt_ue_xj_towards.Draw('same')
h1_mc_ue_xj_towards.SetYTitle("<#SigmaE_{T}/#delta#eta#delta#phi> [GeV]") 
h1_mc_ue_xj_towards.SetXTitle("x_{j}")
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_xj_towards_topoclusters.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_xj_towards_topoclusters.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.48,.56,.92,.84)
leg.AddEntry("","#bf{Transverse Region}","")
leg.AddEntry(h_ue_xj_transverse,"Jet Trig. Data Towers","pl")
leg.AddEntry(h_mc_ue_xj_transverse,"Waveform Towers","pl")
leg.AddEntry(h_clus_ue_xj_transverse,"Cluster Towers","pl")
leg.AddEntry(h_nz_ue_xj_transverse,"No ZS Towers","pl")
leg.AddEntry(h_dt_ue_xj_transverse,"Detroit Waveform Towers","pl")
h_mc_ue_xj_transverse.SetStats(0)
h_clus_ue_xj_transverse.SetStats(0)
h_nz_ue_xj_transverse.SetStats(0)
h_ue_xj_transverse.SetStats(0)
h_dt_ue_xj_transverse.SetStats(0)
h_mc_ue_xj_transverse.SetLineColor(2)
h_mc_ue_xj_transverse.SetMarkerColor(2)
h_clus_ue_xj_transverse.SetLineColor(4)
h_clus_ue_xj_transverse.SetMarkerColor(4)
h_nz_ue_xj_transverse.SetLineColor(6)
h_nz_ue_xj_transverse.SetMarkerColor(6)
h_ue_xj_transverse.SetLineColor(1)
h_ue_xj_transverse.SetMarkerColor(1)
h_dt_ue_xj_transverse.SetLineColor(7)
h_dt_ue_xj_transverse.SetMarkerColor(7)
h_mc_ue_xj_transverse.SetMarkerStyle(20)
h_clus_ue_xj_transverse.SetMarkerStyle(20)
h_nz_ue_xj_transverse.SetMarkerStyle(20)
h_ue_xj_transverse.SetMarkerStyle(20)
h_dt_ue_xj_transverse.SetMarkerStyle(20)
h_mc_ue_xj_transverse.GetYaxis().SetRangeUser(0,2.7)
h_mc_ue_xj_transverse.Draw()
h_ue_xj_transverse.Draw('same')
h_clus_ue_xj_transverse.Draw('same')
h_nz_ue_xj_transverse.Draw('same')
h_dt_ue_xj_transverse.Draw('same')
h_mc_ue_xj_transverse.SetYTitle("<#SigmaE_{T}/#delta#eta#delta#phi> [GeV]") 
h_mc_ue_xj_transverse.SetXTitle("x_{j}")
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_xj_transverse_towers.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_xj_transverse_towers.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.48,.56,.92,.84)
leg.AddEntry("","#bf{Transverse Region}","")
leg.AddEntry(h1_ue_xj_transverse,"Jet Trig. Data Topoclusters","pl")
leg.AddEntry(h1_mc_ue_xj_transverse,"Waveform Topoclusters","pl")
leg.AddEntry(h1_clus_ue_xj_transverse,"Cluster Topoclusters","pl")
leg.AddEntry(h1_nz_ue_xj_transverse,"No ZS Topoclusters","pl")
leg.AddEntry(h1_dt_ue_xj_transverse,"Detroit Waveform Topoclusters","pl")
h1_mc_ue_xj_transverse.SetStats(0)
h1_clus_ue_xj_transverse.SetStats(0)
h1_nz_ue_xj_transverse.SetStats(0)
h1_ue_xj_transverse.SetStats(0)
h1_dt_ue_xj_transverse.SetStats(0)
h1_mc_ue_xj_transverse.SetLineColor(2)
h1_mc_ue_xj_transverse.SetMarkerColor(2)
h1_clus_ue_xj_transverse.SetLineColor(4)
h1_clus_ue_xj_transverse.SetMarkerColor(4)
h1_nz_ue_xj_transverse.SetLineColor(6)
h1_nz_ue_xj_transverse.SetMarkerColor(6)
h1_ue_xj_transverse.SetLineColor(1)
h1_ue_xj_transverse.SetMarkerColor(1)
h1_dt_ue_xj_transverse.SetLineColor(7)
h1_dt_ue_xj_transverse.SetMarkerColor(7)
h1_mc_ue_xj_transverse.SetMarkerStyle(20)
h1_clus_ue_xj_transverse.SetMarkerStyle(20)
h1_nz_ue_xj_transverse.SetMarkerStyle(20)
h1_ue_xj_transverse.SetMarkerStyle(20)
h1_dt_ue_xj_transverse.SetMarkerStyle(20)
h1_mc_ue_xj_transverse.GetYaxis().SetRangeUser(0,2.7)
h1_mc_ue_xj_transverse.Draw()
h1_ue_xj_transverse.Draw('same')
h1_clus_ue_xj_transverse.Draw('same')
h1_nz_ue_xj_transverse.Draw('same')
h1_dt_ue_xj_transverse.Draw('same')
h1_mc_ue_xj_transverse.SetYTitle("<#SigmaE_{T}/#delta#eta#delta#phi> [GeV]") 
h1_mc_ue_xj_transverse.SetXTitle("x_{j}")
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_xj_transverse_topoclusters.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_xj_transverse_topoclusters.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.48,.64,.92,.92)
leg.AddEntry("","#bf{Away Region}","")
leg.AddEntry(h_ue_xj_away,"Jet Trig. Data Towers","pl")
leg.AddEntry(h_mc_ue_xj_away,"Waveform Towers","pl")
leg.AddEntry(h_clus_ue_xj_away,"Cluster Towers","pl")
leg.AddEntry(h_nz_ue_xj_away,"No ZS Towers","pl")
leg.AddEntry(h_dt_ue_xj_away,"Detroit Waveform Towers","pl")
h_mc_ue_xj_away.SetStats(0)
h_clus_ue_xj_away.SetStats(0)
h_nz_ue_xj_away.SetStats(0)
h_ue_xj_away.SetStats(0)
h_dt_ue_xj_away.SetStats(0)
h_mc_ue_xj_away.SetLineColor(2)
h_mc_ue_xj_away.SetMarkerColor(2)
h_clus_ue_xj_away.SetLineColor(4)
h_clus_ue_xj_away.SetMarkerColor(4)
h_nz_ue_xj_away.SetLineColor(6)
h_nz_ue_xj_away.SetMarkerColor(6)
h_ue_xj_away.SetLineColor(1)
h_ue_xj_away.SetMarkerColor(1)
h_dt_ue_xj_away.SetLineColor(7)
h_dt_ue_xj_away.SetMarkerColor(7)
h_mc_ue_xj_away.SetMarkerStyle(20)
h_clus_ue_xj_away.SetMarkerStyle(20)
h_nz_ue_xj_away.SetMarkerStyle(20)
h_ue_xj_away.SetMarkerStyle(20)
h_dt_ue_xj_away.SetMarkerStyle(20)
h_mc_ue_xj_away.GetYaxis().SetRangeUser(2,10)
h_mc_ue_xj_away.Draw()
h_ue_xj_away.Draw('same')
h_clus_ue_xj_away.Draw('same')
h_nz_ue_xj_away.Draw('same')
h_dt_ue_xj_away.Draw('same')
h_mc_ue_xj_away.SetYTitle("<#SigmaE_{T}/#delta#eta#delta#phi> [GeV]") 
h_mc_ue_xj_away.SetXTitle("x_{j}")
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_xj_away_towers.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_xj_away_towers.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.48,.64,.92,.92)
leg.AddEntry("","#bf{Away Region}","")
leg.AddEntry(h1_ue_xj_away,"Jet Trig. Data Topoclusters","pl")
leg.AddEntry(h1_mc_ue_xj_away,"Waveform Topoclusters","pl")
leg.AddEntry(h1_clus_ue_xj_away,"Cluster Topoclusters","pl")
leg.AddEntry(h1_nz_ue_xj_away,"No ZS Topoclusters","pl")
leg.AddEntry(h1_dt_ue_xj_away,"Detroit Waveform Topoclusters","pl")
h1_mc_ue_xj_away.SetStats(0)
h1_clus_ue_xj_away.SetStats(0)
h1_nz_ue_xj_away.SetStats(0)
h1_ue_xj_away.SetStats(0)
h1_dt_ue_xj_away.SetStats(0)
h1_mc_ue_xj_away.SetLineColor(2)
h1_mc_ue_xj_away.SetMarkerColor(2)
h1_clus_ue_xj_away.SetLineColor(4)
h1_clus_ue_xj_away.SetMarkerColor(4)
h1_nz_ue_xj_away.SetLineColor(6)
h1_nz_ue_xj_away.SetMarkerColor(6)
h1_ue_xj_away.SetLineColor(1)
h1_ue_xj_away.SetMarkerColor(1)
h1_dt_ue_xj_away.SetLineColor(7)
h1_dt_ue_xj_away.SetMarkerColor(7)
h1_mc_ue_xj_away.SetMarkerStyle(20)
h1_clus_ue_xj_away.SetMarkerStyle(20)
h1_nz_ue_xj_away.SetMarkerStyle(20)
h1_ue_xj_away.SetMarkerStyle(20)
h1_dt_ue_xj_away.SetMarkerStyle(20)
h1_mc_ue_xj_away.GetYaxis().SetRangeUser(2,10)
h1_mc_ue_xj_away.Draw()
h1_ue_xj_away.Draw('same')
h1_clus_ue_xj_away.Draw('same')
h1_nz_ue_xj_away.Draw('same')
h1_dt_ue_xj_away.Draw('same')
h1_mc_ue_xj_away.SetYTitle("<#SigmaE_{T}/#delta#eta#delta#phi> [GeV]") 
h1_mc_ue_xj_away.SetXTitle("x_{j}")
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_xj_away_topoclusters.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_xj_away_topoclusters.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.17,.65,.5,.92)
leg.AddEntry("","#bf{Towards Region}","")
leg.AddEntry(h_ue_pt_towards,"Jet Trig. Data Towers","pl")
leg.AddEntry(h_mc_ue_pt_towards,"Waveform Towers","pl")
leg.AddEntry(h_clus_ue_pt_towards,"Cluster Towers","pl")
leg.AddEntry(h_nz_ue_pt_towards,"No ZS Towers","pl")
leg.AddEntry(h_dt_ue_pt_towards,"Detroit Waveform Towers","pl")
h_mc_ue_pt_towards.SetStats(0)
h_clus_ue_pt_towards.SetStats(0)
h_nz_ue_pt_towards.SetStats(0)
h_ue_pt_towards.SetStats(0)
h_dt_ue_pt_towards.SetStats(0)
h_mc_ue_pt_towards.SetLineColor(2)
h_mc_ue_pt_towards.SetMarkerColor(2)
h_clus_ue_pt_towards.SetLineColor(4)
h_clus_ue_pt_towards.SetMarkerColor(4)
h_nz_ue_pt_towards.SetLineColor(6)
h_nz_ue_pt_towards.SetMarkerColor(6)
h_ue_pt_towards.SetLineColor(1)
h_ue_pt_towards.SetMarkerColor(1)
h_dt_ue_pt_towards.SetLineColor(7)
h_dt_ue_pt_towards.SetMarkerColor(7)
h_mc_ue_pt_towards.SetMarkerStyle(20)
h_clus_ue_pt_towards.SetMarkerStyle(20)
h_nz_ue_pt_towards.SetMarkerStyle(20)
h_ue_pt_towards.SetMarkerStyle(20)
h_dt_ue_pt_towards.SetMarkerStyle(20)
h_mc_ue_pt_towards.GetXaxis().SetRangeUser(10,50)
h_mc_ue_pt_towards.GetYaxis().SetRangeUser(3,14)
h_mc_ue_pt_towards.Draw()
h_ue_pt_towards.Draw('same')
h_clus_ue_pt_towards.Draw('same')
h_nz_ue_pt_towards.Draw('same')
h_dt_ue_pt_towards.Draw('same')
h_mc_ue_pt_towards.SetYTitle("<#SigmaE_{T}/#delta#eta#delta#phi> [GeV]") 
h_mc_ue_pt_towards.SetXTitle("p_{T}^{lead} [GeV]")
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_pt_towards_towers.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_pt_towards_towers.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.17,.65,.5,.92)
leg.AddEntry("","#bf{Towards Region}","")
leg.AddEntry(h1_ue_pt_towards,"Jet Trig. Data Topoclusters","pl")
leg.AddEntry(h1_mc_ue_pt_towards,"Waveform Topoclusters","pl")
leg.AddEntry(h1_clus_ue_pt_towards,"Cluster Topoclusters","pl")
leg.AddEntry(h1_nz_ue_pt_towards,"No ZS Topoclusters","pl")
leg.AddEntry(h1_dt_ue_pt_towards,"Detroit Waveform Topoclusters","pl")
h1_mc_ue_pt_towards.SetStats(0)
h1_clus_ue_pt_towards.SetStats(0)
h1_nz_ue_pt_towards.SetStats(0)
h1_ue_pt_towards.SetStats(0)
h1_dt_ue_pt_towards.SetStats(0)
h1_mc_ue_pt_towards.SetLineColor(2)
h1_mc_ue_pt_towards.SetMarkerColor(2)
h1_clus_ue_pt_towards.SetLineColor(4)
h1_clus_ue_pt_towards.SetMarkerColor(4)
h1_nz_ue_pt_towards.SetLineColor(6)
h1_nz_ue_pt_towards.SetMarkerColor(6)
h1_ue_pt_towards.SetLineColor(1)
h1_ue_pt_towards.SetMarkerColor(1)
h1_dt_ue_pt_towards.SetLineColor(7)
h1_dt_ue_pt_towards.SetMarkerColor(7)
h1_mc_ue_pt_towards.SetMarkerStyle(20)
h1_clus_ue_pt_towards.SetMarkerStyle(20)
h1_nz_ue_pt_towards.SetMarkerStyle(20)
h1_ue_pt_towards.SetMarkerStyle(20)
h1_dt_ue_pt_towards.SetMarkerStyle(20)
h1_mc_ue_pt_towards.GetXaxis().SetRangeUser(10,50)
h1_mc_ue_pt_towards.GetYaxis().SetRangeUser(3,14)
h1_mc_ue_pt_towards.Draw()
h1_ue_pt_towards.Draw('same')
h1_clus_ue_pt_towards.Draw('same')
h1_nz_ue_pt_towards.Draw('same')
h1_dt_ue_pt_towards.Draw('same')
h1_mc_ue_pt_towards.SetYTitle("<#SigmaE_{T}/#delta#eta#delta#phi> [GeV]") 
h1_mc_ue_pt_towards.SetXTitle("p_{T}^{lead} [GeV]")
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_pt_towards_topoclusters.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_pt_towards_topoclusters.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.17,.55,.5,.82)
leg.AddEntry("","#bf{Transverse Region}","")
leg.AddEntry(h_ue_pt_transverse,"Jet Trig. Data Towers","pl")
leg.AddEntry(h_mc_ue_pt_transverse,"Waveform Towers","pl")
leg.AddEntry(h_clus_ue_pt_transverse,"Cluster Towers","pl")
leg.AddEntry(h_nz_ue_pt_transverse,"No ZS Towers","pl")
leg.AddEntry(h_dt_ue_pt_transverse,"Detroit Waveform Towers","pl")
h_mc_ue_pt_transverse.SetStats(0)
h_clus_ue_pt_transverse.SetStats(0)
h_nz_ue_pt_transverse.SetStats(0)
h_ue_pt_transverse.SetStats(0)
h_dt_ue_pt_transverse.SetStats(0)
h_mc_ue_pt_transverse.SetLineColor(2)
h_mc_ue_pt_transverse.SetMarkerColor(2)
h_clus_ue_pt_transverse.SetLineColor(4)
h_clus_ue_pt_transverse.SetMarkerColor(4)
h_nz_ue_pt_transverse.SetLineColor(6)
h_nz_ue_pt_transverse.SetMarkerColor(6)
h_ue_pt_transverse.SetLineColor(1)
h_ue_pt_transverse.SetMarkerColor(1)
h_dt_ue_pt_transverse.SetLineColor(7)
h_dt_ue_pt_transverse.SetMarkerColor(7)
h_mc_ue_pt_transverse.SetMarkerStyle(20)
h_clus_ue_pt_transverse.SetMarkerStyle(20)
h_nz_ue_pt_transverse.SetMarkerStyle(20)
h_ue_pt_transverse.SetMarkerStyle(20)
h_dt_ue_pt_transverse.SetMarkerStyle(20)
h_mc_ue_pt_transverse.GetXaxis().SetRangeUser(10,50)
h_mc_ue_pt_transverse.GetYaxis().SetRangeUser(0.3,2.7)
h_mc_ue_pt_transverse.Draw()
h_ue_pt_transverse.Draw('same')
h_clus_ue_pt_transverse.Draw('same')
h_nz_ue_pt_transverse.Draw('same')
h_dt_ue_pt_transverse.Draw('same')
h_mc_ue_pt_transverse.SetYTitle("<#SigmaE_{T}/#delta#eta#delta#phi> [GeV]") 
h_mc_ue_pt_transverse.SetXTitle("p_{T}^{lead} [GeV]")
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_pt_transverse_towers.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_pt_transverse_towers.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.17,.55,.5,.82)
leg.AddEntry("","#bf{Transverse Region}","")
leg.AddEntry(h1_ue_pt_transverse,"Jet Trig. Data Topoclusters","pl")
leg.AddEntry(h1_mc_ue_pt_transverse,"Waveform Topoclusters","pl")
leg.AddEntry(h1_clus_ue_pt_transverse,"Cluster Topoclusters","pl")
leg.AddEntry(h1_nz_ue_pt_transverse,"No ZS Topoclusters","pl")
leg.AddEntry(h1_dt_ue_pt_transverse,"Detroit Waveform Topoclusters","pl")
h1_mc_ue_pt_transverse.SetStats(0)
h1_clus_ue_pt_transverse.SetStats(0)
h1_nz_ue_pt_transverse.SetStats(0)
h1_ue_pt_transverse.SetStats(0)
h1_dt_ue_pt_transverse.SetStats(0)
h1_mc_ue_pt_transverse.SetLineColor(2)
h1_mc_ue_pt_transverse.SetMarkerColor(2)
h1_clus_ue_pt_transverse.SetLineColor(4)
h1_clus_ue_pt_transverse.SetMarkerColor(4)
h1_nz_ue_pt_transverse.SetLineColor(6)
h1_nz_ue_pt_transverse.SetMarkerColor(6)
h1_ue_pt_transverse.SetLineColor(1)
h1_ue_pt_transverse.SetMarkerColor(1)
h1_dt_ue_pt_transverse.SetLineColor(7)
h1_dt_ue_pt_transverse.SetMarkerColor(7)
h1_mc_ue_pt_transverse.SetMarkerStyle(20)
h1_clus_ue_pt_transverse.SetMarkerStyle(20)
h1_nz_ue_pt_transverse.SetMarkerStyle(20)
h1_ue_pt_transverse.SetMarkerStyle(20)
h1_dt_ue_pt_transverse.SetMarkerStyle(20)
h1_mc_ue_pt_transverse.GetXaxis().SetRangeUser(10,50)
h1_mc_ue_pt_transverse.GetYaxis().SetRangeUser(0.3,2.7)
h1_mc_ue_pt_transverse.Draw()
h1_ue_pt_transverse.Draw('same')
h1_clus_ue_pt_transverse.Draw('same')
h1_nz_ue_pt_transverse.Draw('same')
h1_dt_ue_pt_transverse.Draw('same')
h1_mc_ue_pt_transverse.SetYTitle("<#SigmaE_{T}/#delta#eta#delta#phi> [GeV]") 
h1_mc_ue_pt_transverse.SetXTitle("p_{T}^{lead} [GeV]")
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_pt_transverse_topoclusters.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_pt_transverse_topoclusters.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.17,.65,.5,.92)
leg.AddEntry("","#bf{Away Region}","")
leg.AddEntry(h_ue_pt_away,"Jet Trig. Data Towers","pl")
leg.AddEntry(h_mc_ue_pt_away,"Waveform Towers","pl")
leg.AddEntry(h_clus_ue_pt_away,"Cluster Towers","pl")
leg.AddEntry(h_nz_ue_pt_away,"No ZS Towers","pl")
leg.AddEntry(h_dt_ue_pt_away,"Detroit Waveform Towers","pl")
h_mc_ue_pt_away.SetStats(0)
h_clus_ue_pt_away.SetStats(0)
h_nz_ue_pt_away.SetStats(0)
h_ue_pt_away.SetStats(0)
h_dt_ue_pt_away.SetStats(0)
h_mc_ue_pt_away.SetLineColor(2)
h_mc_ue_pt_away.SetMarkerColor(2)
h_clus_ue_pt_away.SetLineColor(4)
h_clus_ue_pt_away.SetMarkerColor(4)
h_nz_ue_pt_away.SetLineColor(6)
h_nz_ue_pt_away.SetMarkerColor(6)
h_ue_pt_away.SetLineColor(1)
h_ue_pt_away.SetMarkerColor(1)
h_dt_ue_pt_away.SetLineColor(7)
h_dt_ue_pt_away.SetMarkerColor(7)
h_mc_ue_pt_away.SetMarkerStyle(20)
h_clus_ue_pt_away.SetMarkerStyle(20)
h_nz_ue_pt_away.SetMarkerStyle(20)
h_ue_pt_away.SetMarkerStyle(20)
h_dt_ue_pt_away.SetMarkerStyle(20)
h_mc_ue_pt_away.GetXaxis().SetRangeUser(10,50)
h_mc_ue_pt_away.GetYaxis().SetRangeUser(2.5,13)
h_mc_ue_pt_away.Draw()
h_ue_pt_away.Draw('same')
h_clus_ue_pt_away.Draw('same')
h_nz_ue_pt_away.Draw('same')
h_dt_ue_pt_away.Draw('same')
h_mc_ue_pt_away.SetYTitle("<#SigmaE_{T}/#delta#eta#delta#phi> [GeV]") 
h_mc_ue_pt_away.SetXTitle("p_{T}^{lead} [GeV]")
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_pt_away_towers.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_pt_away_towers.png has been created

# %%
canvas = ROOT.TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.17,.65,.5,.92)
leg.AddEntry("","#bf{Away Region}","")
leg.AddEntry(h1_ue_pt_away,"Jet Trig. Data Topoclusters","pl")
leg.AddEntry(h1_mc_ue_pt_away,"Waveform Topoclusters","pl")
leg.AddEntry(h1_clus_ue_pt_away,"Cluster Topoclusters","pl")
leg.AddEntry(h1_nz_ue_pt_away,"No ZS Topoclusters","pl")
leg.AddEntry(h1_dt_ue_pt_away,"Detroit Waveform Topoclusters","pl")
h1_mc_ue_pt_away.SetStats(0)
h1_clus_ue_pt_away.SetStats(0)
h1_nz_ue_pt_away.SetStats(0)
h1_ue_pt_away.SetStats(0)
h1_dt_ue_pt_away.SetStats(0)
h1_mc_ue_pt_away.SetLineColor(2)
h1_mc_ue_pt_away.SetMarkerColor(2)
h1_clus_ue_pt_away.SetLineColor(4)
h1_clus_ue_pt_away.SetMarkerColor(4)
h1_nz_ue_pt_away.SetLineColor(6)
h1_nz_ue_pt_away.SetMarkerColor(6)
h1_ue_pt_away.SetLineColor(1)
h1_ue_pt_away.SetMarkerColor(1)
h1_dt_ue_pt_away.SetLineColor(7)
h1_dt_ue_pt_away.SetMarkerColor(7)
h1_mc_ue_pt_away.SetMarkerStyle(20)
h1_clus_ue_pt_away.SetMarkerStyle(20)
h1_nz_ue_pt_away.SetMarkerStyle(20)
h1_ue_pt_away.SetMarkerStyle(20)
h1_dt_ue_pt_away.SetMarkerStyle(20)
h1_mc_ue_pt_away.GetXaxis().SetRangeUser(10,50)
h1_mc_ue_pt_away.GetYaxis().SetRangeUser(2.5,13)
h1_mc_ue_pt_away.Draw()
h1_ue_pt_away.Draw('same')
h1_clus_ue_pt_away.Draw('same')
h1_nz_ue_pt_away.Draw('same')
h1_dt_ue_pt_away.Draw('same')
h1_mc_ue_pt_away.SetYTitle("<#SigmaE_{T}/#delta#eta#delta#phi> [GeV]") 
h1_mc_ue_pt_away.SetXTitle("p_{T}^{lead} [GeV]")
leg.SetTextSize(0.035)
leg.Draw()
canvas.Draw()
canvas.SaveAs("/sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_pt_away_topoclusters.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/fall_2024/plots_10_15/h_ue_pt_away_topoclusters.png has been created
